# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('20221227.csv',sep=';')
dados
# Out:
#          COD_IBGE  MUNICIPIO  COD_REGIAO_COVID              REGIAO_COVID  \
# 0          430003     ACEGUÁ                16                BAGE - R22
# 1          430003     ACEGUÁ                16                BAGE - R22
# 2          430003     ACEGUÁ                16                BAGE - R22
# 3          430003     ACEGUÁ                16                BAGE - R22
# 4          430003     ACEGUÁ                16                BAGE - R22
# ...           ...        ...               ...                       ...
# 2871116    432380  XANGRI-LÁ                 3  CAPAO DA CANOA - R04 R05
# 2871117    432380  XANGRI-LÁ                 3  CAPAO DA CANOA - R04 R05
# 2871118    432380  XANGRI-LÁ                 3  CAPAO DA CANOA - R04 R05
# 2871119    432380  XANGRI-LÁ                 3  CAPAO DA CANOA - R04 R05
# 2871120    432380  XANGRI-LÁ                 3  CAPAO DA CANOA - R04 R05
#
#               SEXO FAIXAETARIA      CRITERIO DATA_CONFIRMACAO DATA_SINTOMAS  \
# ...

# %%
filtro = dados.loc[dados['COD_IBGE']==431870]
filtro['DATA_CONFIRMACAO'] = filtro['DATA_CONFIRMACAO'].map(lambda x: str(x)[6:])
filtro
# Out:
# C:\Users\ryan-rosa\AppData\Local\Temp\ipykernel_3004\371210080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro['DATA_CONFIRMACAO'] = filtro['DATA_CONFIRMACAO'].map(lambda x: str(x)[6:])
#          COD_IBGE     MUNICIPIO  COD_REGIAO_COVID         REGIAO_COVID  \
# 2415423    431870  SÃO LEOPOLDO                 5  NOVO HAMBURGO - R07
# 2415424    431870  SÃO LEOPOLDO                 5  NOVO HAMBURGO - R07
# 2415425    431870  SÃO LEOPOLDO                 5  NOVO HAMBURGO - R07
# 2415426    431870  SÃO LEOPOLDO                 5  NOVO HAMBURGO - R07
# 2415427    431870  SÃO LEOPOLDO                 5  NOVO HAMBURGO - R07
# ...           ...           ...               ...                  ...
# ...

# %%
teste = filtro.groupby('DATA_CONFIRMACAO').count()
teste
# Out:
#                   COD_IBGE  MUNICIPIO  COD_REGIAO_COVID  REGIAO_COVID   SEXO  \
# DATA_CONFIRMACAO
# 2020                 13057      13057             13057         13057  13057
# 2021                 16438      16438             16438         16438  16438
# 2022                 18680      18680             18680         18680  18680
#
#                   FAIXAETARIA  CRITERIO  DATA_SINTOMAS  DATA_INCLUSAO  \
# DATA_CONFIRMACAO
# 2020                    13057     13057          13057          13057
# 2021                    16438     16438          16438          16438
# 2022                    18680     18680          18680          18680
#
#                   DATA_EVOLUCAO  ...  DATA_INCLUSAO_OBITO  \
# DATA_CONFIRMACAO                 ...
# 2020                        470  ...                  234
# 2021                       1108  ...                  568
# 2022                        164  ...                   90
#
# ...

# %%
teste['TOTAL_NOTIFICACOES'] = teste['COD_IBGE']
teste
# Out:
#                   COD_IBGE  MUNICIPIO  COD_REGIAO_COVID  REGIAO_COVID   SEXO  \
# DATA_CONFIRMACAO
# 2020                 13057      13057             13057         13057  13057
# 2021                 16438      16438             16438         16438  16438
# 2022                 18680      18680             18680         18680  18680
#
#                   FAIXAETARIA  CRITERIO  DATA_SINTOMAS  DATA_INCLUSAO  \
# DATA_CONFIRMACAO
# 2020                    13057     13057          13057          13057
# 2021                    16438     16438          16438          16438
# 2022                    18680     18680          18680          18680
#
#                   DATA_EVOLUCAO  ...  DATA_EVOLUCAO_ESTIMADA  RACA_COR  \
# DATA_CONFIRMACAO                 ...
# 2020                        470  ...                   12602     13057
# 2021                       1108  ...                   15358     16438
# 2022                        164  ...                   17891     18680
#
# ...

# %%
final = teste['TOTAL_NOTIFICACOES']
final = final.to_frame()
final
# Out:
#                   TOTAL_NOTIFICACOES
# DATA_CONFIRMACAO
# 2020                           13057
# 2021                           16438
# 2022                           18680
