# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['2018','2019','2020','2021','2022']
y = [143003,161171,151712,162104,97780]

# %%
plt.figure(figsize=(20,10))
plt.plot(x,y,linewidth=2,marker='o',linestyle='--')
sns.despine()
plt.yticks(np.arange(90000,180000,5000))
# Out:
# ([<matplotlib.axis.YTick at 0x1e1d1fd6830>,
#   <matplotlib.axis.YTick at 0x1e1d1fd61d0>,
#   <matplotlib.axis.YTick at 0x1e1d1fd5240>,
#   <matplotlib.axis.YTick at 0x1e1d20264d0>,
#   <matplotlib.axis.YTick at 0x1e1d2026290>,
#   <matplotlib.axis.YTick at 0x1e1d20270a0>,
#   <matplotlib.axis.YTick at 0x1e1d20277f0>,
#   <matplotlib.axis.YTick at 0x1e1d20680a0>,
#   <matplotlib.axis.YTick at 0x1e1d20686d0>,
#   <matplotlib.axis.YTick at 0x1e1d2068e20>,
#   <matplotlib.axis.YTick at 0x1e1d2027a90>,
#   <matplotlib.axis.YTick at 0x1e1d2069510>,
#   <matplotlib.axis.YTick at 0x1e1d2068250>,
#   <matplotlib.axis.YTick at 0x1e1d2069c30>,
#   <matplotlib.axis.YTick at 0x1e1d206a380>,
#   <matplotlib.axis.YTick at 0x1e1d206aad0>,
#   <matplotlib.axis.YTick at 0x1e1d206b220>,
#   <matplotlib.axis.YTick at 0x1e1d2027310>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
